# %%
# %pip install matplotlib
# Out:
# Collecting matplotlibNote: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.3.1 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
#   Downloading matplotlib-3.8.2-cp311-cp311-win_amd64.whl.metadata (5.9 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.2.0-cp311-cp311-win_amd64.whl.metadata (5.8 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.47.0-cp311-cp311-win_amd64.whl.metadata (160 kB)
#      ---------------------------------------- 0.0/160.4 kB ? eta -:--:--
#      -- ------------------------------------- 10.2/160.4 kB ? eta -:--:--
#      ----------------------------- -------- 122.9/160.4 kB 1.4 MB/s eta 0:00:01
#      -------------------------------------- 160.4/160.4 kB 1.6 MB/s eta 0:00:00
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.5-cp311-cp311-win_amd64.whl.metadata (6.5 kB)
# Requirement already satisfied: numpy<2,>=1.21 in c:\users\nahra\appdata\roaming\python\python311\site-packages (from matplotlib) (1.26.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\nahra\appdata\roaming\python\python311\site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\nahra\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\nahra\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\nahra\appdata\roaming\python\python311\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\nahra\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Downloading matplotlib-3.8.2-cp311-cp311-win_amd64.whl (7.6 MB)
#    ---------------------------------------- 0.0/7.6 MB ? eta -:--:--
#    - -------------------------------------- 0.3/7.6 MB 8.6 MB/s eta 0:00:01
#    --- ------------------------------------ 0.6/7.6 MB 7.5 MB/s eta 0:00:01
#    ---- ----------------------------------- 0.8/7.6 MB 6.6 MB/s eta 0:00:02
#    ---- ----------------------------------- 0.9/7.6 MB 5.0 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.1/7.6 MB 5.0 MB/s eta 0:00:02
#    ------- -------------------------------- 1.5/7.6 MB 5.6 MB/s eta 0:00:02
#    ---------- ----------------------------- 2.1/7.6 MB 6.6 MB/s eta 0:00:01
#    ------------- -------------------------- 2.6/7.6 MB 7.3 MB/s eta 0:00:01
#    ----------------- ---------------------- 3.3/7.6 MB 8.0 MB/s eta 0:00:01
#    -------------------- ------------------- 3.8/7.6 MB 8.4 MB/s eta 0:00:01
#    ----------------------- ---------------- 4.6/7.6 MB 9.1 MB/s eta 0:00:01
#    ---------------------------- ----------- 5.4/7.6 MB 9.8 MB/s eta 0:00:01
#    ------------------------------ --------- 5.9/7.6 MB 10.2 MB/s eta 0:00:01
#    ---------------------------------- ----- 6.6/7.6 MB 10.3 MB/s eta 0:00:01
#    -------------------------------------- - 7.4/7.6 MB 11.0 MB/s eta 0:00:01
#    ---------------------------------------- 7.6/7.6 MB 10.6 MB/s eta 0:00:00
# Downloading contourpy-1.2.0-cp311-cp311-win_amd64.whl (187 kB)
#    ---------------------------------------- 0.0/187.6 kB ? eta -:--:--
#    --------------------------------------- 187.6/187.6 kB 11.1 MB/s eta 0:00:00
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.47.0-cp311-cp311-win_amd64.whl (2.2 MB)
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    -------------- ------------------------- 0.8/2.2 MB 25.4 MB/s eta 0:00:01
#    ------------------------------- -------- 1.7/2.2 MB 21.9 MB/s eta 0:00:01
#    ---------------------------------------- 2.2/2.2 MB 19.9 MB/s eta 0:00:00
# Downloading kiwisolver-1.4.5-cp311-cp311-win_amd64.whl (56 kB)
#    ---------------------------------------- 0.0/56.1 kB ? eta -:--:--
#    ---------------------------------------- 56.1/56.1 kB 2.9 MB/s eta 0:00:00
# Installing collected packages: kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.2.0 cycler-0.12.1 fonttools-4.47.0 kiwisolver-1.4.5 matplotlib-3.8.2

# %%
import pandas as pd

# Read the table 1 of school leavers' numbers into a Pandas dataframe
df1 = pd.read_sql_table('table1', 'sqlite:///mydata.db')
df1.head()
# Out:
#                 year  2005  2006  2007  2008  2009  2010  2011  2012  2013  \
# 0               Land  Tsd.  Tsd.  Tsd.  Tsd.  Tsd.  Tsd.  Tsd.  Tsd.  Tsd.
# 1  Baden-Württemberg   117   112   112    93    88    91    93    78    72
# 2             Bayern   116   124   114    96    89    96    95    76    76
# 3             Berlin    54    54    38    47    43    42    38    36    34
# 4        Brandenburg    24    26    19    20    19    18    18    15    15
#
#    2014  2015  2016  2017  2018  2019  2020  2021  2022
# 0  Tsd.  Tsd.  Tsd.  Tsd.  Tsd.  Tsd.  Tsd.  Tsd.  Tsd.
# 1    72    76    85    80    89    83    81    98   100
# 2    64    61    79    74    72    74    82   100    98
# 3    33    35    27    31    31    27    24    24    34
# 4    11    12    12    14    14    13          17    18

# %%
import pandas as pd

# Read the table of crime rates into a Pandas dataframe
df2 = pd.read_sql_table('table2', 'sqlite:///mydata.db')
df2.head()
# Out:
#                       2                  3      4  \
# 0              Straftat         Bundesland  Sexus
# 1  Straftaten insgesamt  Baden-Württemberg      M
# 2  Straftaten insgesamt             Bayern      M
# 3  Straftaten insgesamt             Berlin      M
# 4  Straftaten insgesamt        Brandenburg      M
#
#                                             5  \
# 0  Tatverdaechtige deutsch insgesamt - Anzahl
# 1                                     100,465
# 2                                     119,941
# 3                                      51,868
# 4                                      33,703
#
#                                    6                                  7  \
# 0  Kinder bis unter 6 Jahre - Anzahl  Kinder 6 bis unter 8 Jahre Anzahl
# 1                                 21                                152
# 2                                 36                                160
# 3                                 16                                 87
# 4                                  9                                 54
#
#                                       8  \
# 0  Kinder 8 bis unter 10 Jahre - Anzahl
# 1                                   423
# 2                                   480
# 3                                   287
# 4                                   179
#
#                                        9  \
# 0  Kinder 10 bis unter 12 Jahre - Anzahl
# 1                                  1,116
# 2                                  1,328
# 3                                    658
# 4                                    478
#
#                                       10  \
# 0  Kinder 12 bis unter 14 Jahre - Anzahl
# 1                                  2,936
# 2                                  3,261
# 3                                  1,330
# 4                                  1,074
#
#                                                   11  ...  \
# 0  Kinder bis unter 14 Jahre insgesamt (Anzahl Sp...  ...
# 1                                              4,648  ...
# 2                                              5,265  ...
# 3                                              2,378  ...
# 4                                              1,794  ...
#
#                                                   16  \
# 0  Tatverdaechtige insgesamt unter 21 Jahre (Anza...
# 1                                             25,300
# 2                                             29,407
# 3                                             10,505
# 4                                              7,708
#
#                                           17  \
# 0  Erwachsene 21 bis unter 23 Jahre - Anzahl
# 1                                      5,500
# 2                                      6,772
# 3                                      2,347
# 4                                      1,363
#
#                                           18  \
# 0  Erwachsene 23 bis unter 25 Jahre - Anzahl
# 1                                      4,504
# 2                                      5,500
# 3                                      2,162
# 4                                      1,213
#
#                                                   19  \
# 0  Erwachsene 21 bis unter 25 Jahre (Anzahl Spalt...
# 1                                             10,004
# 2                                             12,272
# 3                                              4,509
# 4                                              2,576
#
#                                  20                                21  \
# 0  Erwachsene 25 bis unter 30 Jahre  Erwachsene 30 bis unter 40 Jahre
# 1                             9,805                            17,862
# 2                            11,497                            20,989
# 3                             5,051                            11,601
# 4                             2,374                             7,460
#
#                                  22                                23  \
# 0  Erwachsene 40 bis unter 50 Jahre  Erwachsene 50 bis unter 60 Jahre
# 1                            13,219                            12,735
# 2                            15,768                            15,788
# 3                             8,351                             6,711
# 4                             5,396                             4,302
#
#                                24  \
# 0  Erwachsene 60 Jahre und aelter
# 1                          11,540
# 2                          14,220
# 3                           5,140
# 4                           3,887
#
#                                                   25
# 0  Erwachsene ab 21 Jahre (Anzahl Spalten 19 bis 24)
# 1                                             75,165
# 2                                             90,534
# 3                                             41,363
# 4                                             25,995
#
# [5 rows x 24 columns]

# %%
import pandas as pd

# Read the table 3 representing unemployment numbers into a Pandas dataframe
df3 = pd.read_sql_table('table3', 'sqlite:///mydata.db')
df3.head()
# Out:
#    Years Baden-Württemberg Baden-Württemberg.1 Baden-Württemberg.2  \
# 0      0       Arbeitslose         Arbeitslose         Arbeitslose
# 1      0         Insgesamt            männlich            weiblich
# 2      0            Anzahl              Anzahl              Anzahl
# 3   1991            159318               78974               80344
# 4   1992            191970              100576               91394
#
#         Bayern     Bayern.1     Bayern.2       Berlin     Berlin.1  \
# 0  Arbeitslose  Arbeitslose  Arbeitslose  Arbeitslose  Arbeitslose
# 1    Insgesamt     männlich     weiblich    Insgesamt     männlich
# 2       Anzahl       Anzahl       Anzahl       Anzahl       Anzahl
# 3       214780       111069       103711       179953        96271
# 4       243224       126819       116405       207058       108408
#
#       Berlin.2  ...    Sachsen.2 Sachsen-Anhalt Sachsen-Anhalt.1  \
# 0  Arbeitslose  ...  Arbeitslose    Arbeitslose      Arbeitslose
# 1     weiblich  ...     weiblich      Insgesamt         männlich
# 2       Anzahl  ...       Anzahl         Anzahl           Anzahl
# 3        83682  ...       148014         167127            70899
# 4        98650  ...       210408         217474            76493
#
#   Sachsen-Anhalt.2 Schleswig-Holstein Schleswig-Holstein.1  \
# 0      Arbeitslose        Arbeitslose          Arbeitslose
# 1         weiblich          Insgesamt             männlich
# 2           Anzahl             Anzahl               Anzahl
# 3            96228              80524                45261
# 4           140981              80737                45660
#
#   Schleswig-Holstein.2    Thüringen  Thüringen.1  Thüringen.2
# 0          Arbeitslose  Arbeitslose  Arbeitslose  Arbeitslose
# 1             weiblich    Insgesamt     männlich     weiblich
# 2               Anzahl       Anzahl       Anzahl       Anzahl
# 3                35263       147963        55891        92072
# 4                35077       192748        65195       127553
#
# [5 rows x 49 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Extract the numbers of unemployed in the different federal states in 2022
# and transform to numerical values
federal_states = df3.columns[1::3]
count_2022 = df3.iloc[-1, 1::3]
count_2022 = pd.to_numeric(count_2022, errors='coerce')  # 'coerce' will replace non-numeric values with NaN
#print(federal_states)
#print(count_2022)
plt.plot(federal_states, count_2022, marker='+')
plt.xticks(rotation=90)
plt.ylabel('Unemployed numbers')
# Show the plot
plt.show()

# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import numpy as np

sum_values = np.zeros(12)
index = 0
for i in range(-1, -13, -1):
    count_2022_2011 = df3.iloc[i, 1::3]
    count_2022_2011 = pd.to_numeric(count_2022_2011, errors='coerce')  
    sum_values[index] = count_2022_2011.sum()
    index += 1

rows_val = df3.iloc[-1:-13:-1]
#print(rows_val)
#plt.bar(df3['Years'][-1:-13:-1], sum_values)
plt.plot(df3['Years'][-1:-13:-1], sum_values, marker='+')
plt.xlabel('Years')
plt.ylabel('Unemployed in GER')
plt.show()

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np 

# take the data for male 
stop_idx = df2.index[df2['3']=='Thüringen'].tolist()[0]
print(stop_idx)
federal_states = df2['3'][:stop_idx]
sum_teens = np.zeros(stop_idx)
for i in range(0, stop_idx):
    teens_under14_str = df2.iloc[i,9] 
    teens_14_18_str = df2.iloc[i, 12]
    teens_14_18 = pd.to_numeric(teens_14_18_str.replace(",", ""), errors='coerce')
    teens_under14 = pd.to_numeric(teens_under14_str.replace(",", ""), errors='coerce')
    sum_teens[i] = teens_14_18 + teens_under14
#print(df2['3'][:stop_idx])
plt.plot(federal_states, sum_teens, marker='o')  
plt.xticks(rotation=90)         
plt.show()  

#print(len(df2))
# plot the data for females
print(df2['3'][2*stop_idx+1])
sum_teens_f = np.zeros(stop_idx)
for j in range(stop_idx+2, 2*stop_idx+1):
    teens_under14_f_str = df2.iloc[j, 9]
    teens_14_18_f_str = df2.iloc[j, 12]
    teens_under14_f = pd.to_numeric(teens_under14_f_str.replace(",",""), errors='coerce')
    teens_14_18_f = pd.to_numeric(teens_14_18_f_str.replace(",",""), errors='coerce')
    sum_teens_f[j-stop_idx-2] = teens_under14_f + teens_14_18_f
plt.plot(federal_states, sum_teens_f, marker='o')
plt.xticks(rotation=90)
plt.show()
# Out:
# 16
# Thüringen

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np 

#plot both male and female 
teens_all = np.zeros(stop_idx)
for k in range(stop_idx):
    teens_all[k] = sum_teens[k] + sum_teens_f[k]
plt.plot(federal_states, teens_all, marker='o')
plt.xticks(rotation=90)
plt.show()

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np 

# get the Anteil of criminals under 18 years old
under_18 = 0
for l in range(len(teens_all)):
    under_18 += teens_all[l]
print(int(under_18))
# criminals starting 21 yo 
starting_21_m_str = df2.iloc[stop_idx, -1]
starting_21_m = pd.to_numeric(starting_21_m_str.replace(",",""), errors='coerce')
starting_21_f_str = df2.iloc[2*stop_idx+1, -1]
starting_21_f = pd.to_numeric(starting_21_f_str.replace(",",""), errors='coerce')
starting_21 = starting_21_f + starting_21_m
print(starting_21)

# criminals between 18 yo and 21 yo
between_18_21_m_str = df2.iloc[stop_idx, 13]
between_18_21_m = pd.to_numeric(between_18_21_m_str.replace(",",""), errors='coerce')
between_18_21_f_str = df2.iloc[2*stop_idx+1, 13]
between_18_21_f = pd.to_numeric(between_18_21_f_str.replace(",",""), errors='coerce')
between_18_21_all = between_18_21_f + between_18_21_m 
print(between_18_21_all)

#plot the pie chart to visualize the parts
sizes = [under_18, starting_21, between_18_21_all]
categories = ['Under 18', 'Starting 21', 'Between 18 and 21']
colors = ['#ff9999', '#66b3ff', '#99ff99']

plt.pie(sizes, labels=categories, autopct='%1.1f%%', startangle=90, colors=colors)
plt.show()
# Out:
# 195224
# 1004348
# 106730

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np 

# school droppers 2022
droppers_2022_str = df1.iloc[1:-1,-1]
droppers_2022 = pd.to_numeric(droppers_2022_str, errors='coerce')
federal_states_ = df1['year'][1:-1]
print(federal_states_)
print(droppers_2022)
plt.bar(federal_states_, droppers_2022)
plt.xticks(rotation=90)
plt.show()
# Out:
# 1          Baden-Württemberg
# 2                     Bayern
# 3                     Berlin
# 4                Brandenburg
# 5                     Bremen
# 6                    Hamburg
# 7                     Hessen
# 8     Mecklenburg-Vorpommern
# 9              Niedersachsen
# 10       Nordrhein-Westfalen
# 11           Rheinland-Pfalz
# 12                  Saarland
# 13                   Sachsen
# 14            Sachsen-Anhalt
# 15        Schleswig-Holstein
# 16                 Thüringen
# Name: year, dtype: object
# 1     100
# 2      98
# 3      34
# 4      18
# 5      11
# 6      20
# 7      69
# 8      14
# 9      86
# 10    170
# 11     41
# 12      7
# 13     22
# 14     18
# 15     31
# 16     13
# Name: 2022, dtype: int64

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np 

# Verlauf über die Jahren 2005-2022
years = df1.columns[1:]
print(years)
general = df1.iloc[-1, 1:]
general_num = pd.to_numeric(general, errors='coerce')
print(general_num)

plt.plot( years, general_num, marker='o')
plt.xticks(rotation=75)
plt.show()
# Out:
# Index(['2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022'],
#       dtype='object')
# 2005    943
# 2006    944
# 2007    870
# 2008    791
# 2009    745
# 2010    784
# 2011    765
# 2012    668
# 2013    625
# 2014    574
# 2015    581
# 2016    623
# 2017    614
# 2018    623
# 2019    625
# 2020    617
# 2021    740
# 2022    753
# Name: 17, dtype: int64
